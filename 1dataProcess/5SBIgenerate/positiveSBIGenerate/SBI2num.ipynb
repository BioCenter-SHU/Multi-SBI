# %%
import pandas as pd
SBI = pd.read_table('SBI2.txt',header=None)
SBI = SBI.rename(columns={0:'s1',1:'s1_name',2:'b1',3:'b1_name',4:'sbi', 5:'num'})
SBI
# Out:
#             s1        s1_name       b1                               b1_name  \
# 0      DB00006    Bivalirudin  DB00013                             Urokinase
# 1      DB00006    Bivalirudin  DB00081                           Tositumomab
# 2      DB00006    Bivalirudin  DB00048  Collagenase clostridium histolyticum
# 3      DB00006    Bivalirudin  DB00054                             Abciximab
# 4      DB00006    Bivalirudin  DB06081                          Caplacizumab
# ...        ...            ...      ...                                   ...
# 40954  DB15685  Selpercatinib  DB09036                            Siltuximab
# 40955  DB15685  Selpercatinib  DB11767                             Sarilumab
# 40956  DB15822    Pralsetinib  DB00012                      Darbepoetin alfa
# 40957  DB15822    Pralsetinib  DB00016                        Erythropoietin
# 40958  DB15822    Pralsetinib  DB09046                           Metreleptin
#
#                                                      sbi  num
# 0      name may increase the anticoagulant activities...  0.0
# 1      The risk or severity of bleeding and hemorrhag...  NaN
# 2      The risk or severity of adverse effects can be...  NaN
# 3      The risk or severity of bleeding can be increa...  NaN
# 4      The risk or severity of bleeding can be increa...  NaN
# ...                                                  ...  ...
# 40954  The serum concentration of name can be decreas...  NaN
# 40955  The serum concentration of name can be decreas...  NaN
# 40956  The risk or severity of Thrombosis can be incr...  NaN
# 40957  The risk or severity of Thrombosis can be incr...  NaN
# 40958  The metabolism of name can be increased when c...  NaN
#
# [40959 rows x 6 columns]

# %%
drug_ddi = SBI.sbi
ddi_dict = {}
for ddi in drug_ddi:
    ddi_dict.setdefault(ddi, 0) # 代码简洁、且性能高
    ddi_dict[ddi] +=1

# %%
res = 0
for k,v in ddi_dict.items():
    if(v<10):
        res = res + v
res
# Out:
# 91

# %%
ddi_dict_shanjian = {}
for k,v in ddi_dict.items():
    if(v>9):
        #print(k, '=', v)
        ddi_dict_shanjian[k] = v
    else:
        ddi_dict_shanjian[k] = -91
        
ddi_dict_shanjian
# Out:
# {'name may increase the anticoagulant activities of name.': 349,
#  'The risk or severity of bleeding and hemorrhage can be increased when name is combined with name.': 1083,
#  'The risk or severity of adverse effects can be increased when name is combined with name.': 8074,
#  'The risk or severity of bleeding can be increased when name is combined with name.': 2723,
#  'The therapeutic efficacy of name can be decreased when used in combination with name.': 3597,
#  'The risk or severity of Thrombosis can be increased when name is combined with name.': 456,
#  'name may decrease the excretion rate of name which could result in a higher serum level.': 3631,
#  'name may increase the vasoconstricting activities of name.': 17,
#  'The serum concentration of name can be decreased when it is combined with name.': 89,
#  'The metabolism of name can be increased when combined with name.': 9102,
#  'name may increase the immunosuppressive activities of name.': 219,
#  'The risk or severity of increased transaminases can be increased when name is combined with name.': -91,
#  'name may increase the neutropenic activities of name.': 164,
#  'name may increase the myelosuppressive activities of name.': 82,
#  'The risk or severity of gastrointestinal irritation can be increased when name is combined with name.': 66,
#  'name may increase the antiplatelet activities of name.': 43,
#  'The risk or severity of hypoglycemia can be increased when name is combined with name.': 1685,
#  'name may increase the thrombogenic activities of name.': 1143,
#  'The serum concentration of name can be increased when it is combined with name.': 354,
#  'The risk or severity of hemorrhage can be increased when name is combined with name.': 206,
#  'The metabolism of name can be decreased when combined with name.': 1803,
#  'name may increase the hypotensive activities of name.': 319,
#  'The risk or severity of angioedema can be increased when name is combined with name.': 234,
#  'name may decrease the antihypertensive activities of name.': 18,
#  'The risk or severity of hyperglycemia can be increased when name is combined with name.': 978,
#  'name may increase the orthostatic hypotensive activities of name.': 67,
#  'name may increase the hypoglycemic activities of name.': 787,
#  'name may increase the bradycardic activities of name.': 71,
#  'The risk or severity of cardiotoxicity can be increased when name is combined with name.': 46,
#  'The therapeutic efficacy of name can be increased when used in combination with name.': 1529,
#  'name may increase the gastrointestinal motility reducing activities of name.': 92,
#  'The risk or severity of CNS depression can be increased when name is combined with name.': -91,
#  'name may decrease the hypoglycemic activities of name.': 239,
#  'The risk or severity of myopathy and weakness can be increased when name is combined with name.': 11,
#  'The risk or severity of hypotension can be increased when name is combined with name.': 21,
#  'The risk or severity of hypokalemia can be increased when name is combined with name.': 32,
#  'name may increase the excretion rate of name which could result in a lower serum level and potentially a reduction in efficacy.': 314,
#  'The risk or severity of tendinopathy can be increased when name is combined with name.': 32,
#  'The risk or severity of neutropenia and thrombocytopenia can be increased when name is combined with name.': 137,
#  'The risk or severity of electrolyte imbalance can be increased when name is combined with name.': -91,
#  'name can cause a decrease in the absorption of name resulting in a reduced serum concentration and potentially a decrease in efficacy.': 42,
#  'name may decrease the anticoagulant activities of name.': 564,
#  'name can cause an increase in the absorption of name resulting in an increased serum concentration and potentially a worsening of adverse effects.': 21,
#  'name may increase the sedative activities of name.': -91,
#  'The risk or severity of jaw osteonecrosis and anti-angiogenesis can be increased when name is combined with name.': 16,
#  'The risk or severity of hypocalcemia can be increased when name is combined with name.': -91,
#  'The risk or severity of peripheral neuropathy can be increased when name is combined with name.': 27,
#  'name may increase the hypokalemic activities of name.': -91,
#  'name may increase the hepatotoxic activities of name.': -91,
#  'The risk or severity of Cardiac Arrhythmia can be increased when name is combined with name.': 42,
#  'The risk or severity of neutropenia can be increased when name is combined with name.': 20,
#  'name may increase the central nervous system depressant (CNS depressant) activities of name.': 37,
#  'The risk or severity of hypertension can be increased when name is combined with name.': -91,
#  'name may decrease the cardiotoxic activities of name.': 20,
#  'The risk or severity of congestive heart failure can be increased when name is combined with name.': -91,
#  'name may decrease the neuromuscular blocking activities of name.': 22,
#  'The risk or severity of orthostatic hypotension and syncope can be increased when name is combined with name.': -91,
#  'The risk or severity of pulmonary toxicity can be increased when name is combined with name.': -91,
#  'The risk or severity of sedation can be increased when name is combined with name.': -91,
#  'The risk or severity of liver damage can be increased when name is combined with name.': -91,
#  'The risk or severity of fluid retention can be increased when name is combined with name.': -91,
#  'The risk or severity of edema formation can be increased when name is combined with name.': 21,
#  'The risk or severity of respiratory depression can be increased when name is combined with name.': -91,
#  'name may increase the neuromuscular blocking activities of name.': 33,
#  'The risk or severity of anemia can be increased when name is combined with name.': -91,
#  'The risk or severity of myelosuppression can be increased when name is combined with name.': 68,
#  'The risk or severity of hypotension and orthostatic hypotension can be increased when name is combined with name.': -91,
#  'The risk or severity of bleeding and bruising can be increased when name is combined with name.': 110,
#  'The risk or severity of gastrointestinal bleeding can be increased when name is combined with name.': 12,
#  'The risk or severity of gastrointestinal ulceration and gastrointestinal irritation can be increased when name is combined with name.': -91,
#  'The risk of a hypersensitivity reaction to name is increased when it is combined with name.': -91,
#  'The risk or severity of ulceration can be increased when name is combined with name.': -91,
#  'The risk or severity of hypotension, sedation, death, somnolence, and respiratory depression can be increased when name is combined with name.': -91}

# %%
import numpy as np
SBI = np.array(SBI)

# %%
for i in range(40959):
    print(SBI[i][4])
    if SBI[i][4] in ddi_dict_shanjian:
        SBI[i][5] = ddi_dict_shanjian[SBI[i][4]]
# Out:
# name may increase the anticoagulant activities of name.
# The risk or severity of bleeding and hemorrhage can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The risk or severity of Thrombosis can be increased when name is combined with name.
# The risk or severity of Thrombosis can be increased when name is combined with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# The risk or severity of Thrombosis can be increased when name is combined with name.
# The risk or severity of Thrombosis can be increased when name is combined with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may increase the vasoconstricting activities of name.
# The serum concentration of name can be decreased when it is combined with name.
# The metabolism of name can be increased when combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# The metabolism of name can be increased when combined with name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the immunosuppressive activities of name.
# name may increase the vasoconstricting activities of name.
# The risk or severity of Thrombosis can be increased when name is combined with name.
# The risk or severity of Thrombosis can be increased when name is combined with name.
# The risk or severity of increased transaminases can be increased when name is combined with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# name may increase the neutropenic activities of name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# name may increase the myelosuppressive activities of name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The risk or severity of bleeding can be increased when name is combined with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The metabolism of name can be increased when combined with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# The risk or severity of bleeding and hemorrhage can be increased when name is combined with name.
# The risk or severity of bleeding and hemorrhage can be increased when name is combined with name.
# The risk or severity of bleeding and hemorrhage can be increased when name is combined with name.
# The risk or severity of bleeding and hemorrhage can be increased when name is combined with name.
# The risk or severity of bleeding and hemorrhage can be increased when name is combined with name.
# The risk or severity of bleeding and hemorrhage can be increased when name is combined with name.
# The risk or severity of bleeding and hemorrhage can be increased when name is combined with name.
# The risk or severity of bleeding and hemorrhage can be increased when name is combined with name.
# The risk or severity of bleeding and hemorrhage can be increased when name is combined with name.
# The risk or severity of bleeding and hemorrhage can be increased when name is combined with name.
# The risk or severity of bleeding and hemorrhage can be increased when name is combined with name.
# The risk or severity of bleeding and hemorrhage can be increased when name is combined with name.
# The risk or severity of gastrointestinal irritation can be increased when name is combined with name.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# The risk or severity of bleeding can be increased when name is combined with name.
# name may increase the anticoagulant activities of name.
# name may increase the anticoagulant activities of name.
# name may increase the anticoagulant activities of name.
# name may increase the anticoagulant activities of name.
# name may increase the anticoagulant activities of name.
# name may increase the anticoagulant activities of name.
# name may increase the anticoagulant activities of name.
# name may increase the anticoagulant activities of name.
# name may increase the anticoagulant activities of name.
# name may increase the anticoagulant activities of name.
# name may increase the anticoagulant activities of name.
# name may increase the antiplatelet activities of name.
# name may increase the antiplatelet activities of name.
# The metabolism of name can be increased when combined with name.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# The risk or severity of hypoglycemia can be increased when name is combined with name.
# The risk or severity of hypoglycemia can be increased when name is combined with name.
# The risk or severity of hypoglycemia can be increased when name is combined with name.
# The risk or severity of hypoglycemia can be increased when name is combined with name.
# The risk or severity of hypoglycemia can be increased when name is combined with name.
# The risk or severity of hypoglycemia can be increased when name is combined with name.
# The risk or severity of hypoglycemia can be increased when name is combined with name.
# The risk or severity of hypoglycemia can be increased when name is combined with name.
# The risk or severity of hypoglycemia can be increased when name is combined with name.
# The risk or severity of hypoglycemia can be increased when name is combined with name.
# The risk or severity of hypoglycemia can be increased when name is combined with name.
# The risk or severity of hypoglycemia can be increased when name is combined with name.
# The risk or severity of hypoglycemia can be increased when name is combined with name.
# The risk or severity of hypoglycemia can be increased when name is combined with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The metabolism of name can be increased when combined with name.
# name may increase the thrombogenic activities of name.
# name may increase the thrombogenic activities of name.
# name may increase the thrombogenic activities of name.
# name may increase the thrombogenic activities of name.
# name may increase the thrombogenic activities of name.
# name may increase the thrombogenic activities of name.
# name may increase the thrombogenic activities of name.
# name may increase the thrombogenic activities of name.
# name may increase the thrombogenic activities of name.
# name may increase the thrombogenic activities of name.
# name may increase the thrombogenic activities of name.
# name may increase the thrombogenic activities of name.
# name may increase the thrombogenic activities of name.
# name may increase the thrombogenic activities of name.
# name may increase the thrombogenic activities of name.
# The serum concentration of name can be increased when it is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The risk or severity of hypoglycemia can be increased when name is combined with name.
# The risk or severity of hypoglycemia can be increased when name is combined with name.
# The risk or severity of hypoglycemia can be increased when name is combined with name.
# The risk or severity of hypoglycemia can be increased when name is combined with name.
# The risk or severity of hypoglycemia can be increased when name is combined with name.
# The risk or severity of hypoglycemia can be increased when name is combined with name.
# The risk or severity of hypoglycemia can be increased when name is combined with name.
# The risk or severity of hypoglycemia can be increased when name is combined with name.
# The risk or severity of hemorrhage can be increased when name is combined with name.
# The risk or severity of hemorrhage can be increased when name is combined with name.
# The risk or severity of hemorrhage can be increased when name is combined with name.
# The risk or severity of hemorrhage can be increased when name is combined with name.
# The risk or severity of hemorrhage can be increased when name is combined with name.
# The risk or severity of hemorrhage can be increased when name is combined with name.
# The risk or severity of hemorrhage can be increased when name is combined with name.
# The risk or severity of hemorrhage can be increased when name is combined with name.
# The risk or severity of hemorrhage can be increased when name is combined with name.
# The risk or severity of hemorrhage can be increased when name is combined with name.
# The risk or severity of hemorrhage can be increased when name is combined with name.
# The risk or severity of hemorrhage can be increased when name is combined with name.
# The risk or severity of hemorrhage can be increased when name is combined with name.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be decreased when combined with name.
# The metabolism of name can be decreased when combined with name.
# The metabolism of name can be decreased when combined with name.
# The metabolism of name can be decreased when combined with name.
# The metabolism of name can be decreased when combined with name.
# The metabolism of name can be decreased when combined with name.
# The metabolism of name can be decreased when combined with name.
# The metabolism of name can be decreased when combined with name.
# The metabolism of name can be decreased when combined with name.
# The metabolism of name can be decreased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# name may increase the hypotensive activities of name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of angioedema can be increased when name is combined with name.
# The risk or severity of angioedema can be increased when name is combined with name.
# The risk or severity of angioedema can be increased when name is combined with name.
# The risk or severity of angioedema can be increased when name is combined with name.
# The risk or severity of angioedema can be increased when name is combined with name.
# The risk or severity of angioedema can be increased when name is combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# name may increase the hypotensive activities of name.
# name may decrease the antihypertensive activities of name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of angioedema can be increased when name is combined with name.
# The risk or severity of angioedema can be increased when name is combined with name.
# The risk or severity of angioedema can be increased when name is combined with name.
# The risk or severity of angioedema can be increased when name is combined with name.
# The risk or severity of angioedema can be increased when name is combined with name.
# The risk or severity of angioedema can be increased when name is combined with name.
# The serum concentration of name can be decreased when it is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# name may increase the neutropenic activities of name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The metabolism of name can be increased when combined with name.
# The risk or severity of hyperglycemia can be increased when name is combined with name.
# The risk or severity of hyperglycemia can be increased when name is combined with name.
# The risk or severity of hyperglycemia can be increased when name is combined with name.
# The risk or severity of hyperglycemia can be increased when name is combined with name.
# The risk or severity of hyperglycemia can be increased when name is combined with name.
# The risk or severity of hyperglycemia can be increased when name is combined with name.
# The risk or severity of hyperglycemia can be increased when name is combined with name.
# The risk or severity of hyperglycemia can be increased when name is combined with name.
# The risk or severity of hyperglycemia can be increased when name is combined with name.
# The risk or severity of hyperglycemia can be increased when name is combined with name.
# The risk or severity of hyperglycemia can be increased when name is combined with name.
# The risk or severity of hyperglycemia can be increased when name is combined with name.
# The risk or severity of hyperglycemia can be increased when name is combined with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# name may increase the orthostatic hypotensive activities of name.
# name may increase the orthostatic hypotensive activities of name.
# name may increase the orthostatic hypotensive activities of name.
# name may increase the hypoglycemic activities of name.
# name may increase the hypoglycemic activities of name.
# name may increase the hypoglycemic activities of name.
# name may increase the hypoglycemic activities of name.
# name may increase the hypoglycemic activities of name.
# name may increase the hypoglycemic activities of name.
# name may increase the hypoglycemic activities of name.
# name may increase the hypoglycemic activities of name.
# name may increase the hypoglycemic activities of name.
# name may increase the hypoglycemic activities of name.
# name may increase the hypoglycemic activities of name.
# name may increase the hypoglycemic activities of name.
# name may increase the hypoglycemic activities of name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# The risk or severity of bleeding and hemorrhage can be increased when name is combined with name.
# The risk or severity of bleeding and hemorrhage can be increased when name is combined with name.
# The risk or severity of bleeding and hemorrhage can be increased when name is combined with name.
# The risk or severity of bleeding and hemorrhage can be increased when name is combined with name.
# The risk or severity of bleeding and hemorrhage can be increased when name is combined with name.
# The risk or severity of bleeding and hemorrhage can be increased when name is combined with name.
# The risk or severity of bleeding and hemorrhage can be increased when name is combined with name.
# The risk or severity of bleeding and hemorrhage can be increased when name is combined with name.
# The risk or severity of bleeding and hemorrhage can be increased when name is combined with name.
# The risk or severity of bleeding and hemorrhage can be increased when name is combined with name.
# The risk or severity of bleeding and hemorrhage can be increased when name is combined with name.
# The risk or severity of bleeding and hemorrhage can be increased when name is combined with name.
# The metabolism of name can be decreased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The serum concentration of name can be increased when it is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be decreased when combined with name.
# The metabolism of name can be decreased when combined with name.
# ...
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The metabolism of name can be increased when combined with name.
# name may increase the neutropenic activities of name.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be decreased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of hypoglycemia can be increased when name is combined with name.
# The therapeutic efficacy of name can be increased when used in combination with name.
# The therapeutic efficacy of name can be increased when used in combination with name.
# The therapeutic efficacy of name can be increased when used in combination with name.
# The therapeutic efficacy of name can be increased when used in combination with name.
# The therapeutic efficacy of name can be increased when used in combination with name.
# The therapeutic efficacy of name can be increased when used in combination with name.
# The therapeutic efficacy of name can be increased when used in combination with name.
# The therapeutic efficacy of name can be increased when used in combination with name.
# The therapeutic efficacy of name can be increased when used in combination with name.
# The therapeutic efficacy of name can be increased when used in combination with name.
# The therapeutic efficacy of name can be increased when used in combination with name.
# The therapeutic efficacy of name can be increased when used in combination with name.
# The therapeutic efficacy of name can be increased when used in combination with name.
# name may increase the excretion rate of name which could result in a lower serum level and potentially a reduction in efficacy.
# name may increase the excretion rate of name which could result in a lower serum level and potentially a reduction in efficacy.
# name may increase the excretion rate of name which could result in a lower serum level and potentially a reduction in efficacy.
# name may increase the excretion rate of name which could result in a lower serum level and potentially a reduction in efficacy.
# name may increase the excretion rate of name which could result in a lower serum level and potentially a reduction in efficacy.
# name may increase the excretion rate of name which could result in a lower serum level and potentially a reduction in efficacy.
# name may increase the excretion rate of name which could result in a lower serum level and potentially a reduction in efficacy.
# name may increase the excretion rate of name which could result in a lower serum level and potentially a reduction in efficacy.
# The risk or severity of hyperglycemia can be increased when name is combined with name.
# name may decrease the hypoglycemic activities of name.
# The risk or severity of Thrombosis can be increased when name is combined with name.
# The risk or severity of Thrombosis can be increased when name is combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be decreased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The risk or severity of Thrombosis can be increased when name is combined with name.
# The risk or severity of Thrombosis can be increased when name is combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# name may increase the vasoconstricting activities of name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# name may increase the gastrointestinal motility reducing activities of name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The therapeutic efficacy of name can be decreased when used in combination with name.
# The metabolism of name can be decreased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The risk or severity of adverse effects can be increased when name is combined with name.
# The therapeutic efficacy of name can be increased when used in combination with name.
# The therapeutic efficacy of name can be increased when used in combination with name.
# The therapeutic efficacy of name can be increased when used in combination with name.
# The therapeutic efficacy of name can be increased when used in combination with name.
# The therapeutic efficacy of name can be increased when used in combination with name.
# The therapeutic efficacy of name can be increased when used in combination with name.
# The therapeutic efficacy of name can be increased when used in combination with name.
# The therapeutic efficacy of name can be increased when used in combination with name.
# The therapeutic efficacy of name can be increased when used in combination with name.
# The therapeutic efficacy of name can be increased when used in combination with name.
# The therapeutic efficacy of name can be increased when used in combination with name.
# The therapeutic efficacy of name can be increased when used in combination with name.
# The therapeutic efficacy of name can be increased when used in combination with name.
# The risk or severity of tendinopathy can be increased when name is combined with name.
# The risk or severity of Thrombosis can be increased when name is combined with name.
# The risk or severity of Thrombosis can be increased when name is combined with name.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# name may decrease the excretion rate of name which could result in a higher serum level.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be decreased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The risk or severity of Thrombosis can be increased when name is combined with name.
# The risk or severity of Thrombosis can be increased when name is combined with name.
# The serum concentration of name can be increased when it is combined with name.
# The serum concentration of name can be decreased when it is combined with name.
# The metabolism of name can be decreased when combined with name.
# The metabolism of name can be decreased when combined with name.
# The metabolism of name can be decreased when combined with name.
# The metabolism of name can be decreased when combined with name.
# The metabolism of name can be decreased when combined with name.
# The metabolism of name can be decreased when combined with name.
# The metabolism of name can be decreased when combined with name.
# The metabolism of name can be decreased when combined with name.
# The metabolism of name can be decreased when combined with name.
# The metabolism of name can be decreased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# The metabolism of name can be increased when combined with name.
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
SBI2 = pd.DataFrame(SBI)
SBI2
# Out:
#              0              1        2                                     3  \
# 0      DB00006    Bivalirudin  DB00013                             Urokinase
# 1      DB00006    Bivalirudin  DB00081                           Tositumomab
# 2      DB00006    Bivalirudin  DB00048  Collagenase clostridium histolyticum
# 3      DB00006    Bivalirudin  DB00054                             Abciximab
# 4      DB00006    Bivalirudin  DB06081                          Caplacizumab
# ...        ...            ...      ...                                   ...
# 40954  DB15685  Selpercatinib  DB09036                            Siltuximab
# 40955  DB15685  Selpercatinib  DB11767                             Sarilumab
# 40956  DB15822    Pralsetinib  DB00012                      Darbepoetin alfa
# 40957  DB15822    Pralsetinib  DB00016                        Erythropoietin
# 40958  DB15822    Pralsetinib  DB09046                           Metreleptin
#
#                                                        4     5
# 0      name may increase the anticoagulant activities...   349
# 1      The risk or severity of bleeding and hemorrhag...  1083
# 2      The risk or severity of adverse effects can be...  8074
# 3      The risk or severity of bleeding can be increa...  2723
# 4      The risk or severity of bleeding can be increa...  2723
# ...                                                  ...   ...
# 40954  The serum concentration of name can be decreas...    89
# 40955  The serum concentration of name can be decreas...    89
# 40956  The risk or severity of Thrombosis can be incr...   456
# 40957  The risk or severity of Thrombosis can be incr...   456
# 40958  The metabolism of name can be increased when c...  9102
#
# [40959 rows x 6 columns]

# %%
SBI2.to_csv('SBI_40959_name.txt', sep='\t', header=None, index=False)
